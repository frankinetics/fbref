# %% [markdown]
# # FBREF Web-scraping functions

# %%
import requests
import pandas as pd
from bs4 import BeautifulSoup
import klib as kb
import seaborn as sb
import matplotlib.pyplot as plt
import wes
import matplotlib as mpl
import warnings
import numpy as np
from math import pi
import sys
import os

# %%
sys.path.append(os.path.abspath(os.pardir))

from src.fbref_analysis_functions import *

# %%
warnings.filterwarnings("ignore")

# %%
get_player_data("https://fbref.com/en/players/47a34c4f/Mohamed-Elneny")
# Out:
#              name non_penalty_goals npx_g shots_total assists   x_a  \
# 0  Mohamed Elneny              0.14  0.03        0.60    0.00  0.01
#
#   npx_g_plus_x_a shot_creating_actions passes_attempted  \
# 0           0.05                  1.15            59.43
#
#   pass_completion_percent  ... progressive_carries dribbles_completed  \
# 0                   92.8%  ...                4.35               0.46
#
#   touches_att_pen progressive_passes_rec pressures tackles interceptions  \
# 0            0.37                   0.69     10.81    0.78          1.10
#
#   blocks clearances aerials_won
# 0   0.96       1.28        0.64
#
# [1 rows x 21 columns]

# %%
compare_players_data("https://fbref.com/en/players/47a34c4f/Mohamed-Elneny", "https://fbref.com/en/players/529f49ab/Thomas-Partey")

# %%
compare_players_percentile("https://fbref.com/en/players/867239d3/Paul-Pogba","https://fbref.com/en/players/529f49ab/Thomas-Partey")
