# %% [markdown]
# # FBREF Web-scraping functions

# %%
import requests
import pandas as pd
from bs4 import BeautifulSoup
import klib as kb
import seaborn as sb
import matplotlib.pyplot as plt
import wes
import matplotlib as mpl
import warnings
import numpy as np
from math import pi
import sys
import os

# %%
sys.path.append(os.path.abspath(os.pardir))

from src.fbref_analysis_functions import *

# %%
warnings.filterwarnings("ignore")

# %%
get_player_data("https://fbref.com/en/players/f874dd44/Hector-Bellerin")
# Out:
#               name non_penalty_goals npx_g shots_total assists   x_a  \
# 0  Héctor Bellerín              0.03  0.04        0.68    0.10  0.14
#
#   npx_g_plus_x_a shot_creating_actions passes_attempted  \
# 0           0.18                  1.84            56.70
#
#   pass_completion_percent  ... progressive_carries dribbles_completed  \
# 0                   83.2%  ...                5.12               0.79
#
#   touches_att_pen progressive_passes_rec pressures tackles interceptions  \
# 0            2.25                   2.97      9.32    1.37          0.61
#
#   blocks clearances aerials_won
# 0   1.98       1.95        1.50
#
# [1 rows x 21 columns]

# %%
compare_players_data("https://fbref.com/en/players/31a62dc7/Zeki-Celik", "https://fbref.com/en/players/f874dd44/Hector-Bellerin")

# %%
compare_players_percentile("https://fbref.com/en/players/442b56fa/Ridle-Baku", "https://fbref.com/en/players/f874dd44/Hector-Bellerin")

# %%
compare_defensive_stats("https://fbref.com/en/players/31a62dc7/Zeki-Celik", "https://fbref.com/en/players/f874dd44/Hector-Bellerin")
# Out:
# Zeki Çelik is in the following percentile for defensive performance: 70.0
# Héctor Bellerín is in the following percentile for defensive performance: 30.0
