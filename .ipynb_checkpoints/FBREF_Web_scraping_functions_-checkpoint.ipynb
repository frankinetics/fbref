# %% [markdown]
# # FBREF Web-scraping functions

# %%
import requests
import pandas as pd
from bs4 import BeautifulSoup
import klib as kb
import seaborn as sb
import matplotlib.pyplot as plt
import wes
import matplotlib as mpl
import warnings
import numpy as np
from math import pi
import sys
import os

# %%
sys.path.append(os.path.abspath(os.pardir))

from src.fbref_analysis_functions import *

# %%
warnings.filterwarnings("ignore")

# %%
get_player_data("https://fbref.com/en/players/529f49ab/Thomas-Partey")
# Out:
#             name non_penalty_goals npx_g shots_total assists   x_a  \
# 0  Thomas Partey              0.00  0.06        1.43    0.12  0.05
#
#   npx_g_plus_x_a shot_creating_actions passes_attempted  \
# 0           0.12                  1.74            66.97
#
#   pass_completion_percent  ... progressive_carries dribbles_completed  \
# 0                   87.7%  ...                7.50               1.58
#
#   touches_att_pen progressive_passes_rec pressures tackles interceptions  \
# 0            0.54                   0.93     16.31    2.94          1.51
#
#   blocks clearances aerials_won
# 0   1.74       1.51        1.47
#
# [1 rows x 21 columns]

# %%
compare_players_data("https://fbref.com/en/players/47a34c4f/Mohamed-Elneny", "https://fbref.com/en/players/529f49ab/Thomas-Partey")

# %%
compare_players_percentile("https://fbref.com/en/players/47a34c4f/Mohamed-Elneny","https://fbref.com/en/players/529f49ab/Thomas-Partey")
