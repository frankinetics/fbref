# %% [markdown]
# # Heatmap calculations and statistics

# %%
! pip install statsbomb
# Out:
# Collecting statsbomb
#   Downloading statsbomb-0.3.0-py3-none-any.whl (7.6 kB)
# Requirement already satisfied: PyYAML in /Users/frankhopkins/opt/anaconda3/lib/python3.8/site-packages (from statsbomb) (5.3.1)
# Requirement already satisfied: requests in /Users/frankhopkins/opt/anaconda3/lib/python3.8/site-packages (from statsbomb) (2.24.0)
# Requirement already satisfied: pandas in /Users/frankhopkins/opt/anaconda3/lib/python3.8/site-packages (from statsbomb) (1.2.4)
# Requirement already satisfied: idna<3,>=2.5 in /Users/frankhopkins/opt/anaconda3/lib/python3.8/site-packages (from requests->statsbomb) (2.10)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /Users/frankhopkins/opt/anaconda3/lib/python3.8/site-packages (from requests->statsbomb) (1.25.9)
# Requirement already satisfied: chardet<4,>=3.0.2 in /Users/frankhopkins/opt/anaconda3/lib/python3.8/site-packages (from requests->statsbomb) (3.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/frankhopkins/opt/anaconda3/lib/python3.8/site-packages (from requests->statsbomb) (2021.5.30)
# Requirement already satisfied: python-dateutil>=2.7.3 in /Users/frankhopkins/opt/anaconda3/lib/python3.8/site-packages (from pandas->statsbomb) (2.8.1)
# Requirement already satisfied: pytz>=2017.3 in /Users/frankhopkins/opt/anaconda3/lib/python3.8/site-packages (from pandas->statsbomb) (2020.1)
# Requirement already satisfied: numpy>=1.16.5 in /Users/frankhopkins/opt/anaconda3/lib/python3.8/site-packages (from pandas->statsbomb) (1.18.5)
# Requirement already satisfied: six>=1.5 in /Users/frankhopkins/opt/anaconda3/lib/python3.8/site-packages (from python-dateutil>=2.7.3->pandas->statsbomb) (1.15.0)
# Installing collected packages: statsbomb
# Successfully installed statsbomb-0.3.0

# %%
import statsbomb as statsb
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from matplotlib.patches import Arc
import seaborn as sb

# %%
matches = statsb.Matches(event_id='2', season_id='44')
df = matches.get_dataframe()
df
# Out:
#     match_id  match_date      kick_off competition season home_team away_team  \
# 0    3749257  2004-05-15  16:00:00.000           2     44         1        22
# 1    3749246  2004-03-28  17:05:00.000           2     44         1        39
# 2    3749153  2004-01-10  16:00:00.000           2     44         1        47
# 3    3749642  2004-02-28  16:00:00.000           2     44         1        75
# 4    3749358  2003-08-24  17:05:00.000           2     44        47         1
# 5    3749346  2003-11-01  16:00:00.000           2     44       101         1
# 6    3749253  2003-10-04  13:30:00.000           2     44        24         1
# 7    3749079  2003-10-18  16:00:00.000           2     44         1        33
# 8    3749465  2004-03-13  16:00:00.000           2     44        98         1
# 9    3749133  2004-01-18  15:00:00.000           2     44        59         1
# 10   3749528  2003-09-26  21:00:00.000           2     44         1        37
# 11   3749233  2004-02-01  17:05:00.000           2     44         1        36
# 12   3749462  2004-05-01  13:30:00.000           2     44         1        54
# 13   3749552  2003-09-21  17:05:00.000           2     44        39         1
# 14   3749296  2003-09-13  16:00:00.000           2     44         1       105
# 15   3749454  2003-08-31  17:05:00.000           2     44        36         1
# 16   3749276  2004-02-21  13:30:00.000           2     44        33         1
# 17   3749068  2004-04-25  17:05:00.000           2     44        38         1
# 18   3749310  2003-12-29  21:00:00.000           2     44        25         1
# 19   3749493  2003-08-16  16:00:00.000           2     44         1        29
# 20   3749434  2003-11-22  16:00:00.000           2     44        54         1
# 21   3749192  2003-11-30  15:00:00.000           2     44         1        55
# 22   3749196  2003-11-08  16:00:00.000           2     44         1        38
# 23   3749522  2003-12-26  13:00:00.000           2     44         1        46
# 24   3749448  2004-04-09  13:30:00.000           2     44         1        24
# 25   3749403  2004-03-20  16:00:00.000           2     44         1       328
# 26   3749360  2003-12-14  15:00:00.000           2     44         1        98
# 27   3749453  2004-04-16  21:00:00.000           2     44         1       101
# 28   3749278  2003-12-20  16:00:00.000           2     44       328         1
# 29   3749526  2003-10-26  15:00:00.000           2     44        75         1
# 30   3749052  2004-02-07  16:00:00.000           2     44        46         1
# 31   3749603  2004-05-09  17:05:00.000           2     44        55         1
# 32   3749431  2004-04-11  17:05:00.000           2     44        37         1
#
#     home_score  away_score match_status match_status_360  \
# 0            2           1    available      unscheduled
# 1            1           1    available      unscheduled
# 2            4           1    available      unscheduled
# 3            2           1    available      unscheduled
# 4            0           4    available      unscheduled
# 5            1           4    available      unscheduled
# 6            1           2    available      unscheduled
# 7            2           1    available      unscheduled
# 8            0           2    available      unscheduled
# 9            0           2    available      unscheduled
# 10           3           2    available      unscheduled
# 11           2           1    available      unscheduled
# 12           0           0    available      unscheduled
# 13           0           0    available      unscheduled
# 14           1           1    available      unscheduled
# 15           1           2    available      unscheduled
# 16           1           2    available      unscheduled
# 17           2           2    available      unscheduled
# 18           0           1    available      unscheduled
# 19           2           1    available      unscheduled
# 20           0           3    available      unscheduled
# 21           0           0    available      unscheduled
# 22           2           1    available      unscheduled
# 23           3           0    available      unscheduled
# 24           4           2    available      unscheduled
# 25           2           1    available      unscheduled
# 26           1           0    available      unscheduled
# 27           5           0    available      unscheduled
# 28           1           1    available      unscheduled
# 29           1           1    available      unscheduled
# 30           1           3    available      unscheduled
# 31           0           1    available      unscheduled
# 32           0           0    available      unscheduled
#
#                   last_updated last_updated_360  \
# 0   2020-08-30T08:12:14.579037             None
# 1             2020-07-29T05:00             None
# 2   2020-08-30T08:12:14.579037             None
# 3             2020-07-29T05:00             None
# 4             2020-07-29T05:00             None
# 5             2020-07-29T05:00             None
# 6             2020-07-29T05:00             None
# 7             2020-07-29T05:00             None
# 8             2020-07-29T05:00             None
# 9             2020-07-29T05:00             None
# 10            2020-07-29T05:00             None
# 11            2020-07-29T05:00             None
# 12            2020-07-29T05:00             None
# 13            2020-07-29T05:00             None
# 14            2020-07-29T05:00             None
# 15            2020-07-29T05:00             None
# 16            2020-07-29T05:00             None
# 17            2020-07-29T05:00             None
# 18  2020-08-31T20:40:28.969635             None
# 19            2020-07-29T05:00             None
# 20            2020-07-29T05:00             None
# 21  2020-08-30T07:13:01.092744             None
# 22            2020-07-29T05:00             None
# 23            2020-07-29T05:00             None
# 24            2020-07-29T05:00             None
# 25            2020-07-29T05:00             None
# 26            2020-07-29T05:00             None
# 27  2020-08-31T20:40:28.969635             None
# 28  2020-08-30T07:13:01.092744             None
# 29            2020-07-29T05:00             None
# 30            2020-07-29T05:00             None
# 31            2020-07-29T05:00             None
# 32            2020-07-29T05:00             None
#
#                                              metadata  match_week  \
# 0   {'data_version': '1.1.0', 'shot_fidelity_versi...          38
# 1   {'data_version': '1.1.0', 'shot_fidelity_versi...          30
# 2   {'data_version': '1.1.0', 'shot_fidelity_versi...          21
# 3   {'data_version': '1.1.0', 'shot_fidelity_versi...          27
# 4   {'data_version': '1.1.0', 'shot_fidelity_versi...           2
# 5   {'data_version': '1.1.0', 'shot_fidelity_versi...          11
# 6   {'data_version': '1.1.0', 'shot_fidelity_versi...           8
# 7   {'data_version': '1.1.0', 'shot_fidelity_versi...           9
# 8   {'data_version': '1.1.0', 'shot_fidelity_versi...          28
# 9   {'data_version': '1.1.0', 'shot_fidelity_versi...          22
# 10  {'data_version': '1.1.0', 'shot_fidelity_versi...           7
# 11  {'data_version': '1.1.0', 'shot_fidelity_versi...          23
# 12  {'data_version': '1.1.0', 'shot_fidelity_versi...          35
# 13  {'data_version': '1.1.0', 'shot_fidelity_versi...           6
# 14  {'data_version': '1.1.0', 'shot_fidelity_versi...           5
# 15  {'data_version': '1.1.0', 'shot_fidelity_versi...           4
# 16  {'data_version': '1.1.0', 'shot_fidelity_versi...          26
# 17  {'data_version': '1.1.0', 'shot_fidelity_versi...          35
# 18  {'data_version': '1.1.0', 'shot_fidelity_versi...           1
# 19  {'data_version': '1.1.0', 'shot_fidelity_versi...           1
# 20  {'data_version': '1.1.0', 'shot_fidelity_versi...          13
# 21  {'data_version': '1.1.0', 'shot_fidelity_versi...          14
# 22  {'data_version': '1.1.0', 'shot_fidelity_versi...          12
# 23  {'data_version': '1.1.0', 'shot_fidelity_versi...          18
# 24  {'data_version': '1.1.0', 'shot_fidelity_versi...          31
# 25  {'data_version': '1.1.0', 'shot_fidelity_versi...          29
# 26  {'data_version': '1.1.0', 'shot_fidelity_versi...          16
# 27  {'data_version': '1.1.0', 'shot_fidelity_versi...          33
# 28  {'data_version': '1.1.0', 'shot_fidelity_versi...           1
# 29  {'data_version': '1.1.0', 'shot_fidelity_versi...          10
# 30  {'data_version': '1.1.0', 'shot_fidelity_versi...          24
# 31  {'data_version': '1.1.0', 'shot_fidelity_versi...          37
# 32  {'data_version': '1.1.0', 'shot_fidelity_versi...          32
#
#                       competition_stage                       referee
# 0   {'id': 1, 'name': 'Regular Season'}  {'id': 1279, 'name': 'None'}
# 1   {'id': 1, 'name': 'Regular Season'}  {'id': 1279, 'name': 'None'}
# 2   {'id': 1, 'name': 'Regular Season'}  {'id': 1279, 'name': 'None'}
# 3   {'id': 1, 'name': 'Regular Season'}  {'id': 1279, 'name': 'None'}
# 4   {'id': 1, 'name': 'Regular Season'}  {'id': 1279, 'name': 'None'}
# 5   {'id': 1, 'name': 'Regular Season'}  {'id': 1279, 'name': 'None'}
# 6   {'id': 1, 'name': 'Regular Season'}  {'id': 1279, 'name': 'None'}
# 7   {'id': 1, 'name': 'Regular Season'}  {'id': 1279, 'name': 'None'}
# 8   {'id': 1, 'name': 'Regular Season'}  {'id': 1279, 'name': 'None'}
# 9   {'id': 1, 'name': 'Regular Season'}  {'id': 1279, 'name': 'None'}
# 10  {'id': 1, 'name': 'Regular Season'}  {'id': 1279, 'name': 'None'}
# 11  {'id': 1, 'name': 'Regular Season'}  {'id': 1279, 'name': 'None'}
# 12  {'id': 1, 'name': 'Regular Season'}  {'id': 1279, 'name': 'None'}
# 13  {'id': 1, 'name': 'Regular Season'}  {'id': 1279, 'name': 'None'}
# 14  {'id': 1, 'name': 'Regular Season'}  {'id': 1279, 'name': 'None'}
# 15  {'id': 1, 'name': 'Regular Season'}  {'id': 1279, 'name': 'None'}
# 16  {'id': 1, 'name': 'Regular Season'}  {'id': 1279, 'name': 'None'}
# 17  {'id': 1, 'name': 'Regular Season'}  {'id': 1279, 'name': 'None'}
# 18  {'id': 1, 'name': 'Regular Season'}  {'id': 1279, 'name': 'None'}
# 19  {'id': 1, 'name': 'Regular Season'}  {'id': 1279, 'name': 'None'}
# 20  {'id': 1, 'name': 'Regular Season'}  {'id': 1279, 'name': 'None'}
# 21  {'id': 1, 'name': 'Regular Season'}  {'id': 1279, 'name': 'None'}
# 22  {'id': 1, 'name': 'Regular Season'}  {'id': 1279, 'name': 'None'}
# 23  {'id': 1, 'name': 'Regular Season'}  {'id': 1279, 'name': 'None'}
# 24  {'id': 1, 'name': 'Regular Season'}  {'id': 1279, 'name': 'None'}
# 25  {'id': 1, 'name': 'Regular Season'}  {'id': 1279, 'name': 'None'}
# 26  {'id': 1, 'name': 'Regular Season'}  {'id': 1279, 'name': 'None'}
# 27  {'id': 1, 'name': 'Regular Season'}  {'id': 1279, 'name': 'None'}
# 28  {'id': 1, 'name': 'Regular Season'}  {'id': 1279, 'name': 'None'}
# 29  {'id': 1, 'name': 'Regular Season'}  {'id': 1279, 'name': 'None'}
# 30  {'id': 1, 'name': 'Regular Season'}  {'id': 1279, 'name': 'None'}
# 31  {'id': 1, 'name': 'Regular Season'}  {'id': 1279, 'name': 'None'}
# 32  {'id': 1, 'name': 'Regular Season'}  {'id': 1279, 'name': 'None'}

# %%
events = statsb.Events(event_id='3749246')
df = events.get_dataframe(event_type='pass')
df_arsenal = df[df['possession_team'].isin(['Arsenal'])]

# %%
df_arsenal.head()
# Out:
#   event_type                                    id  index  period  \
# 0       pass  58c0143b-5ffc-4c94-94a5-4295f8398afe      5       1
# 1       pass  5000dc60-5a82-4420-9932-ac70bf135228      8       1
# 2       pass  2a7afafb-3bdc-4bce-8cf7-03e736154ff0     11       1
# 3       pass  3813da72-bc84-4e0b-80cd-657ddba414ef     14       1
# 4       pass  04ec28c7-6052-43c1-ba42-7052dd8f4810     17       1
#
#       timestamp  minute  second  possession possession_team   play_pattern  \
# 0  00:00:01.834       0       1           2         Arsenal  From Kick Off
# 1  00:00:03.645       0       3           2         Arsenal  From Kick Off
# 2  00:00:06.991       0       6           2         Arsenal  From Kick Off
# 3  00:00:10.570       0      10           2         Arsenal  From Kick Off
# 4  00:00:12.652       0      12           2         Arsenal  From Kick Off
#
#    ... through_ball cross cut_back switch  shot_assist goal_assist  \
# 0  ...         None  None     None   None         None        None
# 1  ...         None  None     None   None         None        None
# 2  ...         None  None     None   None         None        None
# 3  ...         None  None     None   None         None        None
# 4  ...         None  None     None   None         None        None
#
#   start_location_x  start_location_y  end_location_x end_location_y
# 0             60.0              40.0            59.2           38.4
# 1             57.8              40.7            38.9           63.1
# 2             38.3              60.5            31.4           27.1
# 3             31.0              25.9            36.9            4.3
# 4             34.5               4.7            27.9           20.1
#
# [5 rows x 37 columns]

# %%
fig, ax = plt.subplots()

fig.set_size_inches(25,10)

#Plot one - include shade
plt.subplot(121)
sb.kdeplot(
    data=df_arsenal, x="start_location_x", y="start_location_y", hue="possession_team", fill = True, alpha=0.7, linewidth=5, palette = "rocket")

plt.show()

plt.show()
# Out:
# /Users/frankhopkins/opt/anaconda3/lib/python3.8/site-packages/seaborn/distributions.py:1182: UserWarning: The following kwargs were not used by contour: 'linewidth'
#   cset = contour_func(

# %%
fig, ax = plt.subplots()

fig.set_size_inches(25,7.5)

#Plot one - include shade
plt.subplot(121)
sb.kdeplot(
    data=df_arsenal, x="start_location_x", y="start_location_y", hue="possession_team", fill = True, alpha=0.7, linewidth=5, palette = "rocket")

plt.ylim(0, 90)
plt.xlim(0, 130)

plt.show()
# Out:
# /Users/frankhopkins/opt/anaconda3/lib/python3.8/site-packages/seaborn/distributions.py:1182: UserWarning: The following kwargs were not used by contour: 'linewidth'
#   cset = contour_func(

# %%
fig, ax = plt.subplots()

fig.set_size_inches(25,7.5)

#Plot one - include shade
plt.subplot(121)
sb.kdeplot(
    data=df_arsenal, x="start_location_x", y="start_location_y", hue="possession_team", fill = True, alpha=0.7, linewidth=5, palette = "rocket")

plt.ylim(0, 90)
plt.xlim(0, 130)

plt.show()
# Out:
# /Users/frankhopkins/opt/anaconda3/lib/python3.8/site-packages/seaborn/distributions.py:1182: UserWarning: The following kwargs were not used by contour: 'linewidth'
#   cset = contour_func(

# %%
#Create figure
fig=plt.figure()
fig.set_size_inches(25,15)
ax=fig.add_subplot(1,1,1)

#Pitch Outline & Centre Line
plt.plot([0,0],[0,90], color="black")
plt.plot([0,130],[90,90], color="black")
plt.plot([130,130],[90,0], color="black")
plt.plot([130,0],[0,0], color="black")
plt.plot([65,65],[0,90], color="black")

#Left Penalty Area
plt.plot([16.5,16.5],[65,25],color="black")
plt.plot([0,16.5],[65,65],color="black")
plt.plot([16.5,0],[25,25],color="black")

#Right Penalty Area
plt.plot([130,113.5],[65,65],color="black")
plt.plot([113.5,113.5],[65,25],color="black")
plt.plot([113.5,130],[25,25],color="black")

#Left 6-yard Box
plt.plot([0,5.5],[54,54],color="black")
plt.plot([5.5,5.5],[54,36],color="black")
plt.plot([5.5,0.5],[36,36],color="black")

#Right 6-yard Box
plt.plot([130,124.5],[54,54],color="black")
plt.plot([124.5,124.5],[54,36],color="black")
plt.plot([124.5,130],[36,36],color="black")

#Prepare Circles
centreCircle = plt.Circle((65,45),9.15,color="black",fill=False)
centreSpot = plt.Circle((65,45),0.8,color="black")
leftPenSpot = plt.Circle((11,45),0.8,color="black")
rightPenSpot = plt.Circle((119,45),0.8,color="black")

#Draw Circles
ax.add_patch(centreCircle)
ax.add_patch(centreSpot)
ax.add_patch(leftPenSpot)
ax.add_patch(rightPenSpot)

#Prepare Arcs
leftArc = Arc((11,45),height=18.3,width=18.3,angle=0,theta1=310,theta2=50,color="black")
rightArc = Arc((119,45),height=18.3,width=18.3,angle=0,theta1=130,theta2=230,color="black")

#Draw Arcs
ax.add_patch(leftArc)
ax.add_patch(rightArc)

#Tidy Axes
plt.axis('off')

sb.kdeplot(
    data=df_arsenal, x="start_location_x", y="start_location_y", hue="possession_team", fill = True, alpha=0.7, linewidth=5, palette = "rocket")
plt.ylim(0, 90)
plt.xlim(0, 130)

#Display Pitch
plt.show()
# Out:
# /Users/frankhopkins/opt/anaconda3/lib/python3.8/site-packages/seaborn/distributions.py:1182: UserWarning: The following kwargs were not used by contour: 'linewidth'
#   cset = contour_func(
