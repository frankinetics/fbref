# %% [markdown]
# # FBREF Web-scraping functions - player comps

# %%
import requests
import pandas as pd
from bs4 import BeautifulSoup
import klib as kb
import seaborn as sb
import matplotlib.pyplot as plt
import wes
import matplotlib as mpl
import warnings
import numpy as np
from math import pi
import sys
import os
import wes
from sklearn.cluster import KMeans
from sklearn.datasets import make_blobs

# %%
sys.path.append(os.path.abspath(os.pardir))

from src.fbref_analysis_functions import *

# %%
warnings.filterwarnings("ignore")

# %%
compare_players_data("https://fbref.com/en/players/f586779e/Tammy-Abraham", "https://fbref.com/en/players/9dbb75ca/Alexandre-Lacazette")

# %%
compare_players_percentile("https://fbref.com/en/players/ee38d9c5/James-Maddison", "https://fbref.com/en/players/79300479/Martin-Odegaard")

# %%
compare_defensive_stats("https://fbref.com/en/players/ee38d9c5/James-Maddison", "https://fbref.com/en/players/79300479/Martin-Odegaard")
# Out:
# James Maddison is in the following percentile for defensive performance: 24.33
# Martin Ødegaard is in the following percentile for defensive performance: 28.33

# %%
compare_offensive_stats("https://fbref.com/en/players/ee38d9c5/James-Maddison", "https://fbref.com/en/players/79300479/Martin-Odegaard")
# Out:
# James Maddison is in the following percentile for offensive performance: 70.33
# Martin Ødegaard is in the following percentile for offensive performance: 48.17
