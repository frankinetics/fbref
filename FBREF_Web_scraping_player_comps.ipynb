# %% [markdown]
# # FBREF Web-scraping functions - player comps

# %%
import requests
import pandas as pd
from bs4 import BeautifulSoup
import klib as kb
import seaborn as sb
import matplotlib.pyplot as plt
import wes
import matplotlib as mpl
import warnings
import numpy as np
from math import pi
import sys
import os
import wes
from sklearn.cluster import KMeans
from sklearn.datasets import make_blobs

# %%
sys.path.append(os.path.abspath(os.pardir))

from src.fbref_analysis_functions import *

# %%
warnings.filterwarnings("ignore")

# %%
compare_players_data("https://fbref.com/en/players/d5dd5f1f/Pierre-Emerick-Aubameyang", "https://fbref.com/en/players/9dbb75ca/Alexandre-Lacazette", "https://fbref.com/en/players/b0b4fd3e/Jack-Grealish")

# %%
compare_players_percentile("https://fbref.com/en/players/ee38d9c5/James-Maddison", "https://fbref.com/en/players/b0b4fd3e/Jack-Grealish")

# %%
compare_defensive_stats("https://fbref.com/en/players/ee38d9c5/James-Maddison", "https://fbref.com/en/players/b0b4fd3e/Jack-Grealish")
# Out:
# James Maddison is in the following percentile for defensive performance: 24.0
# Jack Grealish is in the following percentile for defensive performance: 34.5

# %%
compare_offensive_stats("https://fbref.com/en/players/ee38d9c5/James-Maddison", "https://fbref.com/en/players/b0b4fd3e/Jack-Grealish")
# Out:
# James Maddison is in the following percentile for offensive performance: 70.58
# Jack Grealish is in the following percentile for offensive performance: 81.0

# %%
compare_offensive_stats_three("https://fbref.com/en/players/d5dd5f1f/Pierre-Emerick-Aubameyang", "https://fbref.com/en/players/9dbb75ca/Alexandre-Lacazette", "https://fbref.com/en/players/f7036e1c/Lautaro-Martinez")
# Out:
# Pierre-Emerick Aubameyang is in the following percentile for offensive performance: 52.25
# Alexandre Lacazette is in the following percentile for offensive performance: 51.17
# Lautaro Martínez is in the following percentile for offensive performance: 74.0
